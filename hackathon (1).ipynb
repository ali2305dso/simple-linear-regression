# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\DeLL\\OneDrive\\Desktop\\nmims\\DigiHack Dataset.csv")

# %%
data.describe()
# Out:
#                 ID          Age  Months_in_city  Months_in_current_job  \
# count  3980.000000  3979.000000     3976.000000           3.980000e+03
# mean   1906.401759    38.353606      174.176811           1.030009e+03
# std    1146.057937     8.387179      172.142957           5.469251e+04
# min       1.000000     2.000000        0.000000           0.000000e+00
# 25%     909.750000    32.000000        0.000000           4.000000e+00
# 50%    1904.500000    38.000000      120.000000           4.800000e+01
# 75%    2899.250000    44.000000      300.000000           1.200000e+02
# max    3895.000000    71.000000      744.000000           3.441168e+06
#
#        Bank_balance    Debt_ratio       Target        ENQ_1        ENQ_2  \
# count  3.344000e+03  3.980000e+03  3980.000000  3980.000000  3980.000000
# mean   1.426380e+05  8.693371e+03     0.077387   183.677638   164.062563
# std    1.130916e+06  5.733927e+04     0.267238   395.595808   417.334608
# min   -2.965788e+06  0.000000e+00     0.000000     0.000000     0.000000
# 25%    9.428250e+03  3.000000e-01     0.000000     9.000000     0.000000
# 50%    2.543200e+04  4.700000e-01     0.000000    38.000000    16.000000
# 75%    7.204150e+04  5.900000e-01     0.000000   156.000000    94.000000
# max    4.667487e+07  1.311486e+06     1.000000  4492.000000  4388.000000
#
#              ENQ_3  ...   ACCOUNT_12   ACCOUNT_13   ACCOUNT_14   ACCOUNT_15  \
# count  3980.000000  ...  3980.000000  3980.000000  3980.000000  3980.000000
# mean      1.539950  ...     5.923367     0.671608     3.074372     2.422111
# std       2.188793  ...     7.880766     1.362053     4.286193     2.876832
# min       0.000000  ...     1.000000     0.000000     0.000000     0.000000
# 25%       0.000000  ...     1.000000     0.000000     0.000000     1.000000
# 50%       1.000000  ...     3.000000     0.000000     2.000000     2.000000
# 75%       2.000000  ...     7.000000     1.000000     4.000000     3.000000
# max      24.000000  ...   109.000000    24.000000    37.000000    64.000000
#
#         ACCOUNT_16   ACCOUNT_17    ACCOUNT_18    ACCOUNT_19    ACCOUNT_20  \
# count  3980.000000  3980.000000  3.980000e+03  3.980000e+03  3.980000e+03
# mean      0.487940     1.374121  1.660992e+06  1.394830e+06  2.661650e+05
# std       0.905766     1.901041  7.601363e+06  7.102065e+06  1.502936e+06
# min       0.000000     0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%       0.000000     0.000000  1.434575e+04  0.000000e+00  0.000000e+00
# 50%       0.000000     1.000000  2.002835e+05  3.522800e+04  4.444000e+03
# 75%       1.000000     2.000000  1.072006e+06  8.727002e+05  1.066508e+05
# max      15.000000    18.000000  2.485371e+08  2.415865e+08  3.422155e+07
#
#         ACCOUNT_21
# count  3980.000000
# mean    621.135176
# std     702.175916
# min       0.000000
# 25%     188.750000
# 50%     430.500000
# 75%     792.500000
# max    5311.000000
#
# [8 rows x 28 columns]

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#      ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 0  1794  40.0       SALARIED        70,891       62,491     MALE
# 1  3183  35.0       SALARIED        53,617       53,617     MALE
# 2  1841  46.0       SALARIED        20,000       45,912     MALE
# 3  1115  49.0       SALARIED        40,000       77,440   FEMALE
# 4  3125  45.0  SELF EMPLOYED        36,526       36,526     MALE
#
#   Type_of_industry Marital_Status  Months_in_city  Months_in_current_job  ...  \
# 0           OTHERS        MARRIED           229.0                    108  ...
# 1           OTHERS        MARRIED           408.0                     60  ...
# 2           OTHERS        MARRIED           552.0                    204  ...
# 3           OTHERS        MARRIED             0.0                      0  ...
# 4           OTHERS        MARRIED           540.0                     22  ...
#
#   ACCOUNT_12  ACCOUNT_13  ACCOUNT_14  ACCOUNT_15  ACCOUNT_16  ACCOUNT_17  \
# 0          9           0           8           2           0           2
# 1          8           0           6           1           0           0
# 2          4           2           1           1           1           0
# 3          1           1           0           1           1           0
# 4          2           0           0           1           0           0
#
#    ACCOUNT_18  ACCOUNT_19  ACCOUNT_20  ACCOUNT_21
# 0      275606           0      275606        5311
# 1        4844        4824          20        5289
# 2       15695       15695           0        5153
# 3      480051      480051           0        5143
# 4        2781        2781           0        5093
#
# [5 rows x 35 columns]

# %%
dt=df.dropna()
dt
# Out:
#         ID   Age  Customer_type  Gross_income   Net_income      SEX  \
# 0     1794  40.0       SALARIED        70,891       62,491     MALE
# 1     3183  35.0       SALARIED        53,617       53,617     MALE
# 2     1841  46.0       SALARIED        20,000       45,912     MALE
# 3     1115  49.0       SALARIED        40,000       77,440   FEMALE
# 4     3125  45.0  SELF EMPLOYED        36,526       36,526     MALE
# ...    ...   ...            ...            ...          ...     ...
# 3975  3862  42.0       SALARIED        49,711       49,655   FEMALE
# 3976  3868  60.0  SELF EMPLOYED           -            -       MALE
# 3977  3878  46.0       SALARIED        35,000       25,714     MALE
# 3978  3078  38.0       SALARIED        19,275       22,336     MALE
# 3979  3890  36.0  SELF EMPLOYED        28,527       28,527     MALE
#
#             Type_of_industry Marital_Status  Months_in_city  \
# 0                     OTHERS        MARRIED           229.0
# 1                     OTHERS        MARRIED           408.0
# 2                     OTHERS        MARRIED           552.0
# 3                     OTHERS        MARRIED             0.0
# 4                     OTHERS        MARRIED           540.0
# ...                      ...            ...             ...
# 3975                    FMCG        MARRIED           300.0
# 3976                  OTHERS        MARRIED           120.0
# 3977                  OTHERS        MARRIED           120.0
# 3978  INSTITUTIONS AND TRUST        MARRIED           420.0
# 3979                  OTHERS        MARRIED           120.0
#
#       Months_in_current_job  ... ACCOUNT_12  ACCOUNT_13  ACCOUNT_14  \
# 0                       108  ...          9           0           8
# 1                        60  ...          8           0           6
# 2                       204  ...          4           2           1
# 3                         0  ...          1           1           0
# 4                        22  ...          2           0           0
# ...                     ...  ...        ...         ...         ...
# 3975                      0  ...          6           0           2
# 3976                    240  ...          2           0           0
# 3977                      0  ...          3           0           2
# 3978                     60  ...          2           1           1
# 3979                    120  ...          2           0           1
#
#       ACCOUNT_15  ACCOUNT_16  ACCOUNT_17  ACCOUNT_18  ACCOUNT_19  ACCOUNT_20  \
# 0              2           0           2      275606           0      275606
# 1              1           0           0        4844        4824          20
# 2              1           1           0       15695       15695           0
# 3              1           1           0      480051      480051           0
# 4              1           0           0        2781        2781           0
# ...          ...         ...         ...         ...         ...         ...
# 3975           0           0           0           0           0           0
# 3976           0           0           0           0           0           0
# 3977           0           0           0           0           0           0
# 3978           0           0           0    16237844    16237844           0
# 3979           0           0           0           0           0           0
#
#       ACCOUNT_21
# 0           5311
# 1           5289
# 2           5153
# 3           5143
# 4           5093
# ...          ...
# 3975           0
# 3976           0
# 3977           0
# 3978           0
# 3979           0
#
# [3339 rows x 35 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
corr = dt.corr()
plt.figure(figsize=(5,20))
sns.heatmap(corr, annot = True, cmap="BuPu")

# %%
corr=dt.corr()

# %%
corr
# Out:
#                              ID       Age  Months_in_city  \
# ID                     1.000000  0.017074        0.018792
# Age                    0.017074  1.000000        0.191561
# Months_in_city         0.018792  0.191561        1.000000
# Months_in_current_job -0.019910 -0.007661        0.010155
# Bank_balance           0.026606  0.036543        0.012292
# Debt_ratio            -0.153487  0.001811       -0.002857
# Target                -0.057678  0.004039        0.038655
# ENQ_1                 -0.012403  0.068853        0.029323
# ENQ_2                 -0.039869  0.077309        0.018175
# ENQ_3                  0.030293 -0.028172       -0.066423
# ENQ_4                  0.012585 -0.000609       -0.046636
# ENQ_5                  0.014474 -0.037558       -0.070820
# ENQ_6                 -0.008041  0.021845       -0.043388
# ENQ_7                  0.018422  0.046466       -0.027863
# ENQ_8                 -0.015565  0.091841       -0.014380
# ACCOUNT_9              0.005075  0.045471        0.020460
# ACCOUNT_10             0.033693  0.046210        0.015299
# ACCOUNT_11             0.001871  0.089287        0.021856
# ACCOUNT_12             0.067818  0.076186        0.024473
# ACCOUNT_13            -0.029104  0.133133        0.019542
# ACCOUNT_14             0.087022  0.067775        0.012260
# ACCOUNT_15             0.066022  0.017693       -0.023268
# ACCOUNT_16            -0.024316  0.105721        0.007721
# ACCOUNT_17             0.080403 -0.040803       -0.032695
# ACCOUNT_18             0.001523  0.082859       -0.015238
# ACCOUNT_19             0.001906  0.079506       -0.018021
# ACCOUNT_20            -0.001350  0.043727        0.008420
# ACCOUNT_21             0.037635  0.120872        0.012761
#
#                        Months_in_current_job  Bank_balance  Debt_ratio  \
# ID                                 -0.019910      0.026606   -0.153487
# Age                                -0.007661      0.036543    0.001811
# Months_in_city                      0.010155      0.012292   -0.002857
# Months_in_current_job               1.000000     -0.002102    0.087572
# Bank_balance                       -0.002102      1.000000   -0.010206
# Debt_ratio                          0.087572     -0.010206    1.000000
# Target                             -0.005484     -0.001237    0.053714
# ENQ_1                              -0.005768     -0.007655   -0.002860
# ENQ_2                              -0.007132      0.000057   -0.003333
# ENQ_3                              -0.002906      0.042779   -0.017154
# ENQ_4                              -0.011101      0.042017   -0.009236
# ENQ_5                              -0.001553      0.090119   -0.003310
# ENQ_6                              -0.010688      0.080650   -0.007164
# ENQ_7                              -0.007980      0.209640    0.012384
# ENQ_8                              -0.010523      0.209076   -0.000077
# ACCOUNT_9                          -0.006024     -0.006644   -0.005225
# ACCOUNT_10                         -0.006992     -0.009191    0.007495
# ACCOUNT_11                         -0.009322     -0.009731    0.014229
# ACCOUNT_12                         -0.006151      0.208014    0.001002
# ACCOUNT_13                         -0.007791      0.130848    0.013301
# ACCOUNT_14                          0.000268      0.024042   -0.021453
# ACCOUNT_15                         -0.000791      0.303346    0.001688
# ACCOUNT_16                         -0.010082      0.143172   -0.002678
# ACCOUNT_17                          0.008174      0.004027   -0.007331
# ACCOUNT_18                         -0.003596      0.385726    0.005374
# ACCOUNT_19                         -0.003496      0.403502    0.002713
# ACCOUNT_20                         -0.001679      0.041868    0.014668
# ACCOUNT_21                         -0.007050      0.043431   -0.005434
#
#                          Target     ENQ_1     ENQ_2     ENQ_3  ...  \
# ID                    -0.057678 -0.012403 -0.039869  0.030293  ...
# Age                    0.004039  0.068853  0.077309 -0.028172  ...
# Months_in_city         0.038655  0.029323  0.018175 -0.066423  ...
# Months_in_current_job -0.005484 -0.005768 -0.007132 -0.002906  ...
# Bank_balance          -0.001237 -0.007655  0.000057  0.042779  ...
# Debt_ratio             0.053714 -0.002860 -0.003333 -0.017154  ...
# Target                 1.000000 -0.061092 -0.002352  0.173430  ...
# ENQ_1                 -0.061092  1.000000  0.270884 -0.300245  ...
# ENQ_2                 -0.002352  0.270884  1.000000 -0.156130  ...
# ENQ_3                  0.173430 -0.300245 -0.156130  1.000000  ...
# ENQ_4                  0.080010 -0.282779 -0.227892  0.689812  ...
# ENQ_5                  0.190130 -0.269020 -0.115664  0.783602  ...
# ENQ_6                  0.141127 -0.255196 -0.185676  0.594373  ...
# ENQ_7                  0.143174 -0.194201 -0.017484  0.567571  ...
# ENQ_8                  0.093445 -0.165625 -0.024999  0.426181  ...
# ACCOUNT_9              0.045521 -0.066153  0.014696  0.072264  ...
# ACCOUNT_10             0.060036 -0.086418  0.005409  0.106687  ...
# ACCOUNT_11            -0.058383  0.316800  0.077379 -0.144268  ...
# ACCOUNT_12             0.030835 -0.130419  0.024229  0.272643  ...
# ACCOUNT_13             0.032164 -0.035011  0.126575  0.176414  ...
# ACCOUNT_14             0.057211 -0.142803 -0.004176  0.315847  ...
# ACCOUNT_15             0.077661 -0.159043 -0.002431  0.352165  ...
# ACCOUNT_16             0.053090 -0.019396  0.141520  0.178131  ...
# ACCOUNT_17             0.088006 -0.178971 -0.062104  0.364184  ...
# ACCOUNT_18             0.045060 -0.055786 -0.000073  0.217313  ...
# ACCOUNT_19             0.033641 -0.048997  0.002945  0.190479  ...
# ACCOUNT_20             0.070251 -0.051384 -0.014642  0.202056  ...
# ACCOUNT_21            -0.046373  0.092242  0.193083 -0.001019  ...
#
#                        ACCOUNT_12  ACCOUNT_13  ACCOUNT_14  ACCOUNT_15  \
# ID                       0.067818   -0.029104    0.087022    0.066022
# Age                      0.076186    0.133133    0.067775    0.017693
# Months_in_city           0.024473    0.019542    0.012260   -0.023268
# Months_in_current_job   -0.006151   -0.007791    0.000268   -0.000791
# Bank_balance             0.208014    0.130848    0.024042    0.303346
# Debt_ratio               0.001002    0.013301   -0.021453    0.001688
# Target                   0.030835    0.032164    0.057211    0.077661
# ENQ_1                   -0.130419   -0.035011   -0.142803   -0.159043
# ENQ_2                    0.024229    0.126575   -0.004176   -0.002431
# ENQ_3                    0.272643    0.176414    0.315847    0.352165
# ENQ_4                    0.192869    0.219945    0.199569    0.222672
# ENQ_5                    0.389006    0.268441    0.427094    0.548075
# ENQ_6                    0.272306    0.387854    0.237078    0.348794
# ENQ_7                    0.598091    0.464338    0.613754    0.635148
# ENQ_8                    0.372627    0.723353    0.271387    0.407181
# ACCOUNT_9                0.168968    0.050711    0.165145    0.140951
# ACCOUNT_10               0.221475    0.074557    0.190765    0.163925
# ACCOUNT_11              -0.224112   -0.078045   -0.217287   -0.305311
# ACCOUNT_12               1.000000    0.303006    0.697474    0.682013
# ACCOUNT_13               0.303006    1.000000    0.160274    0.346317
# ACCOUNT_14               0.697474    0.160274    1.000000    0.574576
# ACCOUNT_15               0.682013    0.346317    0.574576    1.000000
# ACCOUNT_16               0.229052    0.850287    0.098285    0.366001
# ACCOUNT_17               0.495514    0.093937    0.745179    0.716240
# ACCOUNT_18               0.326756    0.533508    0.144341    0.496102
# ACCOUNT_19               0.313254    0.540330    0.111090    0.475138
# ACCOUNT_20               0.173791    0.143947    0.208921    0.266107
# ACCOUNT_21               0.140618    0.162516    0.162518    0.121677
#
#                        ACCOUNT_16  ACCOUNT_17  ACCOUNT_18  ACCOUNT_19  \
# ID                      -0.024316    0.080403    0.001523    0.001906
# Age                      0.105721   -0.040803    0.082859    0.079506
# Months_in_city           0.007721   -0.032695   -0.015238   -0.018021
# Months_in_current_job   -0.010082    0.008174   -0.003596   -0.003496
# Bank_balance             0.143172    0.004027    0.385726    0.403502
# Debt_ratio              -0.002678   -0.007331    0.005374    0.002713
# Target                   0.053090    0.088006    0.045060    0.033641
# ENQ_1                   -0.019396   -0.178971   -0.055786   -0.048997
# ENQ_2                    0.141520   -0.062104   -0.000073    0.002945
# ENQ_3                    0.178131    0.364184    0.217313    0.190479
# ENQ_4                    0.200004    0.192717    0.188495    0.169562
# ENQ_5                    0.273548    0.507600    0.363660    0.327167
# ENQ_6                    0.379883    0.228081    0.396306    0.370647
# ENQ_7                    0.372064    0.518556    0.473049    0.437113
# ENQ_8                    0.599074    0.192170    0.561773    0.543809
# ACCOUNT_9                0.053721    0.097544    0.034979    0.023315
# ACCOUNT_10               0.066732    0.108211    0.034295    0.024857
# ACCOUNT_11              -0.097126   -0.301453   -0.083403   -0.074554
# ACCOUNT_12               0.229052    0.495514    0.326756    0.313254
# ACCOUNT_13               0.850287    0.093937    0.533508    0.540330
# ACCOUNT_14               0.098285    0.745179    0.144341    0.111090
# ACCOUNT_15               0.366001    0.716240    0.496102    0.475138
# ACCOUNT_16               1.000000    0.056245    0.552417    0.562338
# ACCOUNT_17               0.056245    1.000000    0.141766    0.096167
# ACCOUNT_18               0.552417    0.141766    1.000000    0.982245
# ACCOUNT_19               0.562338    0.096167    0.982245    1.000000
# ACCOUNT_20               0.135208    0.267868    0.417727    0.239861
# ACCOUNT_21               0.163506    0.073822    0.036007    0.035215
#
#                        ACCOUNT_20  ACCOUNT_21
# ID                      -0.001350    0.037635
# Age                      0.043727    0.120872
# Months_in_city           0.008420    0.012761
# Months_in_current_job   -0.001679   -0.007050
# Bank_balance             0.041868    0.043431
# Debt_ratio               0.014668   -0.005434
# Target                   0.070251   -0.046373
# ENQ_1                   -0.051384    0.092242
# ENQ_2                   -0.014642    0.193083
# ENQ_3                    0.202056   -0.001019
# ENQ_4                    0.154229    0.031878
# ENQ_5                    0.297382   -0.024469
# ENQ_6                    0.255742    0.030643
# ENQ_7                    0.330971    0.148322
# ENQ_8                    0.273366    0.133127
# ACCOUNT_9                0.068091    0.284693
# ACCOUNT_10               0.057085    0.276794
# ACCOUNT_11              -0.070525    0.283367
# ACCOUNT_12               0.173791    0.140618
# ACCOUNT_13               0.143947    0.162516
# ACCOUNT_14               0.208921    0.162518
# ACCOUNT_15               0.266107    0.121677
# ACCOUNT_16               0.135208    0.163506
# ACCOUNT_17               0.267868    0.073822
# ACCOUNT_18               0.417727    0.036007
# ACCOUNT_19               0.239861    0.035215
# ACCOUNT_20               1.000000    0.015786
# ACCOUNT_21               0.015786    1.000000
#
# [28 rows x 28 columns]

# %%
corr=corr(dt['Debt_ratio'],dt['Bank_balance'])
corr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7d17e012e57a> in <module>
# ----> 1 corr=corr(dt['Debt_ratio'],dt['Bank_balance'])
#       2 corr
#
# TypeError: 'DataFrame' object is not callable

# %%
import numpy as np
cols = ['Bank_balance','Debt_ratio',]
f, ax = plt.subplots(figsize=(10, 7))
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)
hm = sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size': 15},yticklabels=cols,xticklabels=cols)
plt.show()

# %%
import numpy as np
cols = ['Bank_balance','Debt_ratio','']
cm = np.corrcoef(df[cols].values.T)
cm
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-aff57f20ebb2> in <module>
#       1 import numpy as np
#       2 cols = ['Bank_balance','Debt_ratio','']
# ----> 3 cm = np.corrcoef(df[cols].values.T)
#       4 cm
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "[''] not in index"

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
X=dt[['Bank_balance','Debt_ratio','ACCOUNT_9','ACCOUNT_10','ACCOUNT_12','ACCOUNT_13','ACCOUNT_14','ACCOUNT_16',
      'ACCOUNT_17','ACCOUNT_15','ACCOUNT_19','ACCOUNT_20','ACCOUNT_21']].values
y=dt[["Target"]].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
model.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Training Accuracy

model.score(X_train,y_train)
# Out:
# 0.926829268292683

# %%
#Testing Accuracy

model.score(X_test,y_test)
# Out:
# 0.9121756487025948

# %%
# classify function
from sklearn.model_selection import cross_val_score
score = cross_val_score(model, X, y, cv=5)
print("Cross validation is",np.mean(score)*100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Cross validation is 91.43357263931338

# %%
expected = y_test
predicted = model.predict(X_test)

# %%
# Importing Libraries and class 

from sklearn import metrics

# %%
#  Printing the Report

print(metrics.classification_report(expected, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       914
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.91      1002
#    macro avg       0.46      0.50      0.48      1002
# weighted avg       0.83      0.91      0.87      1002
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(metrics.confusion_matrix(expected, predicted))
# Out:
# [[914   0]
#  [ 88   0]]

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
model.score(X_train,y_train)
# Out:
# 0.9858793324775353

# %%
model.score(X_test,y_test)
# Out:
# 0.9161676646706587

# %%
# classify function
from sklearn.model_selection import cross_val_score
score = cross_val_score(model, X, y, cv=5)
print("Cross validation is",np.mean(score)*100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Cross validation is 91.88348228077096

# %%
expected = y_test
predicted = model.predict(X_test)

# %%
print(metrics.classification_report(expected, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       914
#            1       0.67      0.09      0.16        88
#
#     accuracy                           0.92      1002
#    macro avg       0.79      0.54      0.56      1002
# weighted avg       0.90      0.92      0.89      1002

# %%
print(metrics.confusion_matrix(expected, predicted))
# Out:
# [[909   5]
#  [ 76  12]]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(expected, predicted)
cm
# Out:
# array([[910,   4],
#        [ 80,   8]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(2,2))
ax=plt.subplot()
sn.set(font_scale=1.2)
sn.heatmap((cm/np.sum(cm)),annot=True,ax=ax,fmt='0.2%')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(-7.5, 0.5, 'Truth')

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
model.score(X_test,y_test)
# Out:
# 0.8762475049900199

# %%
# classify function
from sklearn.model_selection import cross_val_score
score = cross_val_score(model, X, y, cv=5)
print("Cross validation is",np.mean(score)*100)
# Out:
# Cross validation is 81.78814059579592

# %%
expected = y_test
predicted = model.predict(X_test)

# %%
print(metrics.classification_report(expected, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       914
#            1       0.27      0.28      0.28        88
#
#     accuracy                           0.87      1002
#    macro avg       0.60      0.60      0.60      1002
# weighted avg       0.87      0.87      0.87      1002

# %%
print(metrics.confusion_matrix(expected, predicted))
# Out:
# [[846  68]
#  [ 63  25]]

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,f1_score
tree_clf = DecisionTreeClassifier()
tree_clf.fit(X_train,y_train)
y_pred = tree_clf.predict(X_train)
print("Training Data Set Accuracy: ", accuracy_score(y_train,y_pred))
print("Training Data F1 Score ", f1_score(y_train,y_pred))
print("Validation Mean F1 Score: ",cross_val_score(tree_clf,X_train,y_train,cv=5,scoring='f1_macro').mean())
print("Validation Mean Accuracy: ",cross_val_score(tree_clf,X_train,y_train,cv=5,scoring='accuracy').mean())
# Out:
# Training Data Set Accuracy:  1.0
# Training Data F1 Score  1.0
# Validation Mean F1 Score:  0.5184351191519777
# Validation Mean Accuracy:  0.8639192815080363

# %%
training_accuracy = []
val_accuracy = []
training_f1 = []
val_f1 = []
tree_depths = []

for depth in range(1,20):
    tree_clf = DecisionTreeClassifier(max_depth=depth)
    tree_clf.fit(X_train,y_train)
    y_training_pred = tree_clf.predict(X_train)

    training_acc = accuracy_score(y_train,y_training_pred)
    train_f1 = f1_score(y_train,y_training_pred)
    val_mean_f1 = cross_val_score(tree_clf,X_train,y_train,cv=5,scoring='f1_macro').mean()
    val_mean_accuracy = cross_val_score(tree_clf,X_train,y_train,cv=5,scoring='accuracy').mean()
    
    training_accuracy.append(training_acc)
    val_accuracy.append(val_mean_accuracy)
    training_f1.append(train_f1)
    val_f1.append(val_mean_f1)
    tree_depths.append(depth)
    

Tuning_Max_depth = {"Training Accuracy": training_accuracy, "Validation Accuracy": val_accuracy, "Training F1": training_f1, "Validation F1":val_f1, "Max_Depth": tree_depths }
Tuning_Max_depth_df = pd.DataFrame.from_dict(Tuning_Max_depth)

plot_df = Tuning_Max_depth_df.melt('Max_Depth',var_name='Metrics',value_name="Values")
fig,ax = plt.subplots(figsize=(15,5))
sns.pointplot(x="Max_Depth", y="Values",hue="Metrics", data=plot_df,ax=ax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import graphviz 
from sklearn import tree

tree_clf = tree.DecisionTreeClassifier(max_depth = 3)
tree_clf.fit(X_train,y_train)
dot_data = tree.export_graphviz(tree_clf,feature_names = X.columns.tolist())
graph = graphviz.Source(dot_data)
graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-aeb9fd8b4e0a> in <module>
# ----> 1 import graphviz
#       2 from sklearn import tree
#       3
#       4 tree_clf = tree.DecisionTreeClassifier(max_depth = 3)
#       5 tree_clf.fit(X_train,y_train)
#
# ModuleNotFoundError: No module named 'graphviz'
